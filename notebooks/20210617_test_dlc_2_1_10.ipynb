# %%
import deeplabcut

# %% [markdown]
# # 20210617_test_dlc_2_1_10
# Ethan Ho 6/17/2021
#
# ----
#
# The purpose of this notebook is to provide a python environment for testing use cases of DeepLabCut v2.1.10 running in a Singularity container on TACC GPU-enabled clusters. Please see the [README for this repository](https://github.com/eho-tacc/tacc-sing-jhub) for details on setting up a JupyterHub kernel on TACC.

# %% [markdown]
# ## TensorFlow Benchmarks
#
# Runs a ResNet50 from the [official TensorFlow benchmarks repo](https://github.com/tensorflow/benchmarks).

# %%
# %%bash
# [ -d tf-benchmarks ] || git clone --single-branch --branch cnn_tf_v1.15_compatible git@github.com:tensorflow/benchmarks.git
# python3 tf-benchmarks/scripts/tf_cnn_benchmarks/tf_cnn_benchmarks.py --num_gpus=1 --model resnet50 --batch_size 32 --num_batches 200
# Out:
# /opt/conda/bin/python3
# TensorFlow:  1.15
# Model:       resnet50
# Dataset:     imagenet (synthetic)
# Mode:        training
# SingleSess:  False
# Batch size:  32 global
#              32 per device
# Num batches: 200
# Num epochs:  0.00
# Devices:     ['/gpu:0']
# NUMA bind:   False
# Data format: NCHW
# Optimizer:   sgd
# Variables:   parameter_server
# ...
# Generating training model
# Initializing graph
# Running warm up
# Done warm up
# Step	Img/sec	total_loss
# 1	images/sec: 211.2 +/- 0.0 (jitter = 0.0)	8.169
# 10	images/sec: 210.7 +/- 0.1 (jitter = 0.5)	7.593
# 20	images/sec: 210.6 +/- 0.1 (jitter = 0.4)	7.696
# 30	images/sec: 210.6 +/- 0.1 (jitter = 0.4)	7.753
# 40	images/sec: 210.7 +/- 0.1 (jitter = 0.4)	8.007
# 50	images/sec: 210.6 +/- 0.1 (jitter = 0.4)	7.520
# 60	images/sec: 210.6 +/- 0.0 (jitter = 0.4)	7.989
# 70	images/sec: 210.6 +/- 0.0 (jitter = 0.3)	8.026
# 80	images/sec: 210.6 +/- 0.0 (jitter = 0.4)	7.932
# 90	images/sec: 210.7 +/- 0.0 (jitter = 0.4)	7.850
# ...
